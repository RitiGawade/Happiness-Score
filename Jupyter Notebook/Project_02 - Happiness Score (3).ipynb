# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the dataset
df_15 = pd.read_csv("2015.csv")
df_16 = pd.read_csv("2016.csv")
df_17 = pd.read_csv("2017.csv")
df_18 = pd.read_csv("2018.csv")
df_19 = pd.read_csv("2019.csv")
df_20 = pd.read_csv("2020.csv")
df_21 = pd.read_csv("world-happiness-report-2021.csv")
df_2005to2020 = pd.read_csv("world-happiness-report.csv")

# %%
#Reading the data from year 2005 to 2020
df_2005to2020
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0          0.168                      0.882            0.518            0.258
# 1          0.190                      0.850            0.584            0.237
# 2          0.121                      0.707            0.618            0.275
# 3          0.162                      0.731            0.611            0.267
# 4          0.236                      0.776            0.710            0.268
# ...          ...                        ...              ...              ...
# 1944      -0.095                      0.724            0.738            0.209
# 1945      -0.098                      0.751            0.806            0.224
# 1946      -0.068                      0.844            0.710            0.212
# 1947      -0.064                      0.831            0.716            0.235
# 1948      -0.009                      0.789            0.703            0.346
#
# [1949 rows x 11 columns]

# %%
#Renaming the columns of 2005 to 2020 data
df_2005to2020.rename(columns = {'year':'Year',
                       'Country name': 'Country',
                        'Life Ladder':'Happiness score'}, inplace = True)
df_2005to2020
# Out:
#           Country  Year  Happiness score  Log GDP per capita  Social support  \
# 0     Afghanistan  2008            3.724               7.370           0.451
# 1     Afghanistan  2009            4.402               7.540           0.552
# 2     Afghanistan  2010            4.758               7.647           0.539
# 3     Afghanistan  2011            3.832               7.620           0.521
# 4     Afghanistan  2012            3.783               7.705           0.521
# ...           ...   ...              ...                 ...             ...
# 1944     Zimbabwe  2016            3.735               7.984           0.768
# 1945     Zimbabwe  2017            3.638               8.016           0.754
# 1946     Zimbabwe  2018            3.616               8.049           0.775
# 1947     Zimbabwe  2019            2.694               7.950           0.759
# 1948     Zimbabwe  2020            3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 0          0.168                      0.882            0.518            0.258
# 1          0.190                      0.850            0.584            0.237
# 2          0.121                      0.707            0.618            0.275
# 3          0.162                      0.731            0.611            0.267
# 4          0.236                      0.776            0.710            0.268
# ...          ...                        ...              ...              ...
# 1944      -0.095                      0.724            0.738            0.209
# 1945      -0.098                      0.751            0.806            0.224
# 1946      -0.068                      0.844            0.710            0.212
# 1947      -0.064                      0.831            0.716            0.235
# 1948      -0.009                      0.789            0.703            0.346
#
# [1949 rows x 11 columns]

# %%
#Dropping columns from 2005 to 2020 data
df_2005to2020 = df_2005to2020.drop(['Positive affect', 'Negative affect'], axis=1)
df_2005to2020
# Out:
#           Country  Year  Happiness score  Log GDP per capita  Social support  \
# 0     Afghanistan  2008            3.724               7.370           0.451
# 1     Afghanistan  2009            4.402               7.540           0.552
# 2     Afghanistan  2010            4.758               7.647           0.539
# 3     Afghanistan  2011            3.832               7.620           0.521
# 4     Afghanistan  2012            3.783               7.705           0.521
# ...           ...   ...              ...                 ...             ...
# 1944     Zimbabwe  2016            3.735               7.984           0.768
# 1945     Zimbabwe  2017            3.638               8.016           0.754
# 1946     Zimbabwe  2018            3.616               8.049           0.775
# 1947     Zimbabwe  2019            2.694               7.950           0.759
# 1948     Zimbabwe  2020            3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# 2                                51.60                         0.600
# 3                                51.92                         0.496
# 4                                52.24                         0.531
# ...                                ...                           ...
# 1944                             54.40                         0.733
# 1945                             55.00                         0.753
# 1946                             55.60                         0.763
# 1947                             56.20                         0.632
# 1948                             56.80                         0.643
#
#       Generosity  Perceptions of corruption
# 0          0.168                      0.882
# 1          0.190                      0.850
# 2          0.121                      0.707
# 3          0.162                      0.731
# 4          0.236                      0.776
# ...          ...                        ...
# 1944      -0.095                      0.724
# 1945      -0.098                      0.751
# 1946      -0.068                      0.844
# 1947      -0.064                      0.831
# 1948      -0.009                      0.789
#
# [1949 rows x 9 columns]

# %%
#Reading the data of year 2021
df_21
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                   10.775           0.954                   72.000
# 1                   10.933           0.954                   72.700
# 2                   11.117           0.942                   74.400
# 3                   10.878           0.983                   73.000
# 4                   10.932           0.942                   72.400
# ..                     ...             ...                      ...
# 144                  7.926           0.787                   48.700
# 145                  9.782           0.784                   59.269
# 146                  7.676           0.552                   61.400
# 147                  7.943           0.750                   56.201
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# ..                            ...         ...                        ...
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 20 columns]

# %%
#Renaming the columns of 2021 data
df_21.rename(columns = {'Logged GDP per capita':'Log GDP per capita',
                       'Country name': 'Country', 'Regional indicator':'Region',
                        'Ladder score':'Happiness score'}, inplace = True)
df_21
# Out:
#          Country              Region  Happiness score  \
# 0        Finland      Western Europe            7.842
# 1        Denmark      Western Europe            7.620
# 2    Switzerland      Western Europe            7.571
# 3        Iceland      Western Europe            7.554
# 4    Netherlands      Western Europe            7.464
# ..           ...                 ...              ...
# 144      Lesotho  Sub-Saharan Africa            3.512
# 145     Botswana  Sub-Saharan Africa            3.467
# 146       Rwanda  Sub-Saharan Africa            3.415
# 147     Zimbabwe  Sub-Saharan Africa            3.145
# 148  Afghanistan          South Asia            2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ..                              ...           ...           ...
# 144                           0.120         3.748         3.276
# 145                           0.074         3.611         3.322
# 146                           0.068         3.548         3.282
# 147                           0.058         3.259         3.030
# 148                           0.038         2.596         2.449
#
#      Log GDP per capita  Social support  Healthy life expectancy  \
# 0                10.775           0.954                   72.000
# 1                10.933           0.954                   72.700
# 2                11.117           0.942                   74.400
# 3                10.878           0.983                   73.000
# 4                10.932           0.942                   72.400
# ..                  ...             ...                      ...
# 144               7.926           0.787                   48.700
# 145               9.782           0.784                   59.269
# 146               7.676           0.552                   61.400
# 147               7.943           0.750                   56.201
# 148               7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                           0.949      -0.098                      0.186
# 1                           0.946       0.030                      0.179
# 2                           0.919       0.025                      0.292
# 3                           0.955       0.160                      0.673
# 4                           0.913       0.175                      0.338
# ..                            ...         ...                        ...
# 144                         0.715      -0.131                      0.915
# 145                         0.824      -0.246                      0.801
# 146                         0.897       0.061                      0.167
# 147                         0.677      -0.047                      0.821
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 0                        2.43                             1.446
# 1                        2.43                             1.502
# 2                        2.43                             1.566
# 3                        2.43                             1.482
# 4                        2.43                             1.501
# ..                        ...                               ...
# 144                      2.43                             0.451
# 145                      2.43                             1.099
# 146                      2.43                             0.364
# 147                      2.43                             0.457
# 148                      2.43                             0.370
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                           1.106                                  0.741
# 1                           1.108                                  0.763
# 2                           1.079                                  0.816
# 3                           1.172                                  0.772
# 4                           1.079                                  0.753
# ..                            ...                                    ...
# 144                         0.731                                  0.007
# 145                         0.724                                  0.340
# 146                         0.202                                  0.407
# 147                         0.649                                  0.243
# 148                         0.000                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                         0.691                     0.124
# 1                                         0.686                     0.208
# 2                                         0.653                     0.204
# 3                                         0.698                     0.293
# 4                                         0.647                     0.302
# ..                                          ...                       ...
# 144                                       0.405                     0.103
# 145                                       0.539                     0.027
# 146                                       0.627                     0.227
# 147                                       0.359                     0.157
# 148                                       0.000                     0.122
#
#      Explained by: Perceptions of corruption  Dystopia + residual
# 0                                      0.481                3.253
# 1                                      0.485                2.868
# 2                                      0.413                2.839
# 3                                      0.170                2.967
# 4                                      0.384                2.798
# ..                                       ...                  ...
# 144                                    0.015                1.800
# 145                                    0.088                0.648
# 146                                    0.493                1.095
# 147                                    0.075                1.205
# 148                                    0.010                1.895
#
# [149 rows x 20 columns]

# %%
#Dropping columns from 2021 data
df_21 = df_21.drop(['Standard error of ladder score', 'upperwhisker','lowerwhisker','Ladder score in Dystopia','Explained by: Log GDP per capita','Explained by: Social support','Explained by: Healthy life expectancy','Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption','Dystopia + residual'], axis=1)
df_21
# Out:
#          Country              Region  Happiness score  Log GDP per capita  \
# 0        Finland      Western Europe            7.842              10.775
# 1        Denmark      Western Europe            7.620              10.933
# 2    Switzerland      Western Europe            7.571              11.117
# 3        Iceland      Western Europe            7.554              10.878
# 4    Netherlands      Western Europe            7.464              10.932
# ..           ...                 ...              ...                 ...
# 144      Lesotho  Sub-Saharan Africa            3.512               7.926
# 145     Botswana  Sub-Saharan Africa            3.467               9.782
# 146       Rwanda  Sub-Saharan Africa            3.415               7.676
# 147     Zimbabwe  Sub-Saharan Africa            3.145               7.943
# 148  Afghanistan          South Asia            2.523               7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.954                   72.000                         0.949
# 1             0.954                   72.700                         0.946
# 2             0.942                   74.400                         0.919
# 3             0.983                   73.000                         0.955
# 4             0.942                   72.400                         0.913
# ..              ...                      ...                           ...
# 144           0.787                   48.700                         0.715
# 145           0.784                   59.269                         0.824
# 146           0.552                   61.400                         0.897
# 147           0.750                   56.201                         0.677
# 148           0.463                   52.493                         0.382
#
#      Generosity  Perceptions of corruption
# 0        -0.098                      0.186
# 1         0.030                      0.179
# 2         0.025                      0.292
# 3         0.160                      0.673
# 4         0.175                      0.338
# ..          ...                        ...
# 144      -0.131                      0.915
# 145      -0.246                      0.801
# 146       0.061                      0.167
# 147      -0.047                      0.821
# 148      -0.102                      0.924
#
# [149 rows x 9 columns]

# %%
#Concatenating both the datasets together
df_concat = pd.concat([df_2005to2020, df_21],ignore_index = True,sort = False)
print(df_concat)
# Out:
#           Country    Year  Happiness score  Log GDP per capita  \
# 0     Afghanistan  2008.0            3.724               7.370
# 1     Afghanistan  2009.0            4.402               7.540
# 2     Afghanistan  2010.0            4.758               7.647
# 3     Afghanistan  2011.0            3.832               7.620
# 4     Afghanistan  2012.0            3.783               7.705
# ...           ...     ...              ...                 ...
# 2093      Lesotho     NaN            3.512               7.926
# 2094     Botswana     NaN            3.467               9.782
# 2095       Rwanda     NaN            3.415               7.676
# 2096     Zimbabwe     NaN            3.145               7.943
# 2097  Afghanistan     NaN            2.523               7.695
#
#       Social support  Healthy life expectancy at birth  \
# 0              0.451                             50.80
# 1              0.552                             51.20
# 2              0.539                             51.60
# 3              0.521                             51.92
# 4              0.521                             52.24
# ...              ...                               ...
# 2093           0.787                               NaN
# 2094           0.784                               NaN
# 2095           0.552                               NaN
# 2096           0.750                               NaN
# 2097           0.463                               NaN
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                            0.718       0.168                      0.882
# 1                            0.679       0.190                      0.850
# 2                            0.600       0.121                      0.707
# 3                            0.496       0.162                      0.731
# 4                            0.531       0.236                      0.776
# ...                            ...         ...                        ...
# 2093                         0.715      -0.131                      0.915
# 2094                         0.824      -0.246                      0.801
# 2095                         0.897       0.061                      0.167
# 2096                         0.677      -0.047                      0.821
# 2097                         0.382      -0.102                      0.924
#
#                   Region  Healthy life expectancy
# 0                    NaN                      NaN
# 1                    NaN                      NaN
# 2                    NaN                      NaN
# 3                    NaN                      NaN
# 4                    NaN                      NaN
# ...                  ...                      ...
# 2093  Sub-Saharan Africa                   48.700
# 2094  Sub-Saharan Africa                   59.269
# 2095  Sub-Saharan Africa                   61.400
# 2096  Sub-Saharan Africa                   56.201
# 2097          South Asia                   52.493
#
# [2098 rows x 11 columns]

# %%
#Comparing happiness score of 2021 with previous years
sns.kdeplot(df_21['Happiness score'], shade = True, label = '2021 Happiness Score', color = 'r')
sns.kdeplot(df_2005to2020['Happiness score'], shade = True, label = '2021 Happiness Score', color = 'b')
plt.title('2021 Happiness score VS Historical data')
# Out:
# Text(0.5, 1.0, '2021 Happiness score VS Historical data')

# %%
#Finding first 10 countries with highest mean happiness score
plt.figure(figsize = (12,6))
plt.ylabel('Happiness score')
plt.title('First 10 countries with highest mean happiness score')
df_21.groupby('Country')['Happiness score'].mean().sort_values(ascending = False).head(10).plot.bar(color = 'violet')
# Out:
# <AxesSubplot:title={'center':'First 10 countries with highest mean happiness score'}, xlabel='Country', ylabel='Happiness score'>

# %%
#Finding first 10 countries with highest mean happiness score
plt.figure(figsize = (12,6))
plt.ylabel('Happiness score')
plt.title('Last 10 countries with lowest mean happiness score')
df_21.groupby('Country')['Happiness score'].mean().sort_values(ascending = True).head(10).plot.bar(color = 'violet')
# Out:
# <AxesSubplot:title={'center':'Last 10 countries with lowest mean happiness score'}, xlabel='Country', ylabel='Happiness score'>

# %%
countries_CE = ["Czech Republic" ,"Slovenia" ,"Kosovo" ,"Slovakia","Lithuania",
               "Estonia","Poland","Romania","Serbia","Latvia","Hungary",
               "Croatia","Bosnia and Herzegovina","Montenegro","Bulgaria",
               "Albania","North Macedonia"]
mask = df_concat[df_concat.Country.isin(countries_CE)]
mask
# Out:
#                      Country    Year  Happiness score  Log GDP per capita  \
# 12                   Albania  2007.0            4.634               9.142
# 13                   Albania  2009.0            5.485               9.262
# 14                   Albania  2010.0            5.269               9.303
# 15                   Albania  2011.0            5.867               9.331
# 16                   Albania  2012.0            5.510               9.347
# ...                      ...     ...              ...                 ...
# 2012  Bosnia and Herzegovina     NaN            5.813               9.590
# 2020              Montenegro     NaN            5.581               9.940
# 2036                Bulgaria     NaN            5.266              10.016
# 2041                 Albania     NaN            5.117               9.520
# 2042         North Macedonia     NaN            5.101               9.693
#
#       Social support  Healthy life expectancy at birth  \
# 12             0.821                             65.80
# 13             0.833                             66.20
# 14             0.733                             66.40
# 15             0.759                             66.68
# 16             0.785                             66.96
# ...              ...                               ...
# 2012           0.870                               NaN
# 2020           0.858                               NaN
# 2036           0.931                               NaN
# 2041           0.697                               NaN
# 2042           0.805                               NaN
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 12                           0.529      -0.009                      0.875
# 13                           0.525      -0.158                      0.864
# 14                           0.569      -0.172                      0.726
# 15                           0.487      -0.205                      0.877
# 16                           0.602      -0.169                      0.848
# ...                            ...         ...                        ...
# 2012                         0.706       0.113                      0.931
# 2020                         0.708      -0.034                      0.812
# 2036                         0.788      -0.096                      0.932
# 2041                         0.785      -0.030                      0.901
# 2042                         0.751       0.038                      0.905
#
#                           Region  Healthy life expectancy
# 12                           NaN                      NaN
# 13                           NaN                      NaN
# 14                           NaN                      NaN
# 15                           NaN                      NaN
# 16                           NaN                      NaN
# ...                          ...                      ...
# 2012  Central and Eastern Europe                   68.098
# 2020  Central and Eastern Europe                   68.699
# 2036  Central and Eastern Europe                   67.000
# 2041  Central and Eastern Europe                   68.999
# 2042  Central and Eastern Europe                   65.474
#
# [242 rows x 11 columns]

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=mask, x="Year", y="Happiness score",hue='Country',style='Country',palette='flare',ci = None,markers=True,dashes=False,sizes=(.25, 2.5))
plt.title("Central and Eastern Europe region",fontsize=15);

# %%
countries_NA = ["New Zealand" ,"Australia" ,"United States" ,"Canada"]
mask = df_concat[df_concat.Country.isin(countries_NA)]
mask
# Out:
#             Country    Year  Happiness score  Log GDP per capita  \
# 66        Australia  2005.0            7.341              10.659
# 67        Australia  2007.0            7.285              10.703
# 68        Australia  2008.0            7.254              10.719
# 69        Australia  2010.0            7.450              10.722
# 70        Australia  2011.0            7.406              10.733
# ...             ...     ...              ...                 ...
# 1850  United States  2020.0            7.028              11.001
# 1957    New Zealand     NaN            7.277              10.643
# 1959      Australia     NaN            7.183              10.796
# 1962         Canada     NaN            7.103              10.776
# 1967  United States     NaN            6.951              11.023
#
#       Social support  Healthy life expectancy at birth  \
# 66             0.968                             71.40
# 67             0.965                             71.72
# 68             0.947                             71.88
# 69             0.955                             72.20
# 70             0.967                             72.30
# ...              ...                               ...
# 1850           0.937                             68.10
# 1957           0.948                               NaN
# 1959           0.940                               NaN
# 1962           0.926                               NaN
# 1967           0.920                               NaN
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 66                           0.935         NaN                      0.390
# 67                           0.891       0.347                      0.513
# 68                           0.916       0.305                      0.431
# 69                           0.932       0.317                      0.366
# 70                           0.945       0.369                      0.382
# ...                            ...         ...                        ...
# 1850                         0.850       0.034                      0.678
# 1957                         0.929       0.134                      0.242
# 1959                         0.914       0.159                      0.442
# 1962                         0.915       0.089                      0.415
# 1967                         0.837       0.098                      0.698
#
#                      Region  Healthy life expectancy
# 66                      NaN                      NaN
# 67                      NaN                      NaN
# 68                      NaN                      NaN
# 69                      NaN                      NaN
# 70                      NaN                      NaN
# ...                     ...                      ...
# 1850                    NaN                      NaN
# 1957  North America and ANZ                     73.4
# 1959  North America and ANZ                     73.9
# 1962  North America and ANZ                     73.8
# 1967  North America and ANZ                     68.2
#
# [62 rows x 11 columns]

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=mask, x="Year", y="Happiness score",hue='Country')
plt.title("North America and ANZ region",fontsize=10);

# %%
countries_SA = ["Nepal" ,"Maldives" ,"Bangladesh" ,"Pakistan","Sri Lanka","India","Afghanistan"]
mask = df_concat[df_concat.Country.isin(countries_SA)]
mask
# Out:
#           Country    Year  Happiness score  Log GDP per capita  \
# 0     Afghanistan  2008.0            3.724               7.370
# 1     Afghanistan  2009.0            4.402               7.540
# 2     Afghanistan  2010.0            4.758               7.647
# 3     Afghanistan  2011.0            3.832               7.620
# 4     Afghanistan  2012.0            3.783               7.705
# ...           ...     ...              ...                 ...
# 2049   Bangladesh     NaN            5.025               8.454
# 2053     Pakistan     NaN            4.934               8.458
# 2077    Sri Lanka     NaN            4.325               9.470
# 2087        India     NaN            3.819               8.755
# 2097  Afghanistan     NaN            2.523               7.695
#
#       Social support  Healthy life expectancy at birth  \
# 0              0.451                             50.80
# 1              0.552                             51.20
# 2              0.539                             51.60
# 3              0.521                             51.92
# 4              0.521                             52.24
# ...              ...                               ...
# 2049           0.693                               NaN
# 2053           0.651                               NaN
# 2077           0.827                               NaN
# 2087           0.603                               NaN
# 2097           0.463                               NaN
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                            0.718       0.168                      0.882
# 1                            0.679       0.190                      0.850
# 2                            0.600       0.121                      0.707
# 3                            0.496       0.162                      0.731
# 4                            0.531       0.236                      0.776
# ...                            ...         ...                        ...
# 2049                         0.877      -0.041                      0.682
# 2053                         0.726       0.098                      0.787
# 2077                         0.841       0.079                      0.863
# 2087                         0.893       0.089                      0.774
# 2097                         0.382      -0.102                      0.924
#
#           Region  Healthy life expectancy
# 0            NaN                      NaN
# 1            NaN                      NaN
# 2            NaN                      NaN
# 3            NaN                      NaN
# 4            NaN                      NaN
# ...          ...                      ...
# 2049  South Asia                   64.800
# 2053  South Asia                   58.709
# 2077  South Asia                   67.299
# 2087  South Asia                   60.633
# 2097  South Asia                   52.493
#
# [91 rows x 11 columns]

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=mask, x="Year", y="Happiness score",hue='Country')
plt.title("South Asia region",fontsize=10);

# %%
sns.lineplot(x="Year", y="Happiness score",data=df_2005to2020)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Happiness score'>

# %%
#Highly correlated variables pointing towards Happiness score
plt.figure(figsize=(18, 6))
heatmap = sns.heatmap(df_21.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=5);

# %%
sns.pairplot(df_21[['Country', 'Region', 'Happiness score', 'Log GDP per capita',
       'Social support', 'Healthy life expectancy','Generosity',
       'Perceptions of corruption',
       'Freedom to make life choices']], hue="Region")

# %%
df_21
# Out:
#          Country              Region  Happiness score  Log GDP per capita  \
# 0        Finland      Western Europe            7.842              10.775
# 1        Denmark      Western Europe            7.620              10.933
# 2    Switzerland      Western Europe            7.571              11.117
# 3        Iceland      Western Europe            7.554              10.878
# 4    Netherlands      Western Europe            7.464              10.932
# ..           ...                 ...              ...                 ...
# 144      Lesotho  Sub-Saharan Africa            3.512               7.926
# 145     Botswana  Sub-Saharan Africa            3.467               9.782
# 146       Rwanda  Sub-Saharan Africa            3.415               7.676
# 147     Zimbabwe  Sub-Saharan Africa            3.145               7.943
# 148  Afghanistan          South Asia            2.523               7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             0.954                   72.000                         0.949
# 1             0.954                   72.700                         0.946
# 2             0.942                   74.400                         0.919
# 3             0.983                   73.000                         0.955
# 4             0.942                   72.400                         0.913
# ..              ...                      ...                           ...
# 144           0.787                   48.700                         0.715
# 145           0.784                   59.269                         0.824
# 146           0.552                   61.400                         0.897
# 147           0.750                   56.201                         0.677
# 148           0.463                   52.493                         0.382
#
#      Generosity  Perceptions of corruption
# 0        -0.098                      0.186
# 1         0.030                      0.179
# 2         0.025                      0.292
# 3         0.160                      0.673
# 4         0.175                      0.338
# ..          ...                        ...
# 144      -0.131                      0.915
# 145      -0.246                      0.801
# 146       0.061                      0.167
# 147      -0.047                      0.821
# 148      -0.102                      0.924
#
# [149 rows x 9 columns]

# %%
sns.boxplot(x="Region", y="Happiness scoe", data=df_21,whis=[0,100],width=.6, palette="vlag",dodge=True)
plt.figure(figsize=(25,10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-b29546d3a05d> in <module>
# ----> 1 sns.boxplot(x="Region", y="Happiness scoe", data=df_21,whis=[0,100],width=.6, palette="vlag",dodge=True)
#       2 plt.figure(figsize=(25,10))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# -> 2240     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2241                           orient, color, palette, saturation,
#    2242                           width, dodge, fliersize, linewidth)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Happiness scoe'

# %%
Healthy_Life = sns.lmplot(y = "Healthy life expectancy", x = "Happiness score", data = df_21)
Healthy_Life = Healthy_Life.set(title = "Healthy Life Expectancy vs. Happiness Score")

# %%
Social_support = sns.lmplot(y = "Social support", x = "Happiness score", data = df_21)
Social_Support = Social_support.set(title = "Social Impact vs. Happiness Score")

# %%
Generosity = sns.lmplot(y = "Generosity", x = "Happiness score", data = df_21)
Generosity = Generosity.set(title = "Generosity vs. Happiness Score")

# %%
Corruption = sns.lmplot(y = "Perceptions of corruption", x = "Happiness score", data = df_21)
Corruption = Corruption.set(title = "Perceptions of corruption vs. Happiness Score")
